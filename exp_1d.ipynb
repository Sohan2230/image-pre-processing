# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow # Import cv2_imshow

# Load an image using OpenCV
image = cv2.imread('/content/sohan.png')

# Normalize the image to [0, 1] by dividing by 255.0
normalized_image = image / 255.0

# Display the original and normalized images using cv2_imshow
cv2_imshow(image) # Use cv2_imshow instead of cv2.imshow
cv2_imshow(normalized_image) # Use cv2_imshow instead of cv2.imshow

# cv2.waitKey(0) # These functions are not needed with cv2_imshow
# cv2.destroyAllWindows() # These functions are not needed with cv2_imshow
# Out:
# <PIL.Image.Image image mode=RGB size=500x560>
# <PIL.Image.Image image mode=RGB size=500x560>

# %%
import cv2
import numpy as np

# Load an image using OpenCV
image = cv2.imread('/content/sohan.png')

# Normalize the image to [0, 1] by dividing by 255.0
normalized_image = image / 255.0

# Display the original and normalized images
cv2.imshow('Original Image', image)
cv2.imshow('Normalized Image', normalized_image)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# DisabledFunctionError                     Traceback (most recent call last)
# <ipython-input-1-aa285259f5ed> in <cell line: 0>()
#       9
#      10 # Display the original and normalized images
# ---> 11 cv2.imshow('Original Image', image)
#      12 cv2.imshow('Normalized Image', normalized_image)
#      13
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_import_hooks/_cv2.py in wrapped(*args, **kwargs)
#      46   def wrapped(*args, **kwargs):
#      47     if not os.environ.get(env_var, False):
# ---> 48       raise DisabledFunctionError(message, name or func.__name__)
#      49     return func(*args, **kwargs)
#      50
#
# DisabledFunctionError: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
